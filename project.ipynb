# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as  py

# %%
trip_df = pd.read_csv('Travel details dataset.csv')

# %%
trip_df
# Out:
#      Trip ID             Destination Start date   End date  Duration (days)  \
# 0          1              London, UK   5/1/2023   5/8/2023              7.0
# 1          2        Phuket, Thailand  6/15/2023  6/20/2023              5.0
# 2          3         Bali, Indonesia   7/1/2023   7/8/2023              7.0
# 3          4           New York, USA  8/15/2023  8/29/2023             14.0
# 4          5            Tokyo, Japan  9/10/2023  9/17/2023              7.0
# ..       ...                     ...        ...        ...              ...
# 134      135  Rio de Janeiro, Brazil   8/1/2023  8/10/2023              9.0
# 135      136       Vancouver, Canada  8/15/2023  8/21/2023              6.0
# 136      137       Bangkok, Thailand   9/1/2023   9/8/2023              7.0
# 137      138        Barcelona, Spain  9/15/2023  9/22/2023              7.0
# 138      139   Auckland, New Zealand  10/1/2023  10/8/2023              7.0
#
# ...

# %%
plt.figure(figsize=(2,1))
sns.displot(x=trip_df['Traveler age']);
plt.xlabel('Traveler age')
plt.title('Traveler age')
sns.despine()

# %%
a=trip_df['Traveler nationality'].value_counts().sort_values(ascending=False).head(5)
print(a)
a.plot(kind='pie',autopct='%0.1f%%',startangle=90)
plt.ylabel('')
plt.title('Traveler nationality')
# Out:
# American      24
# Korean        13
# British       12
# Canadian       9
# Australian     8
# Name: Traveler nationality, dtype: int64
# Text(0.5, 1.0, 'Traveler nationality')

# %%
def substr_country(x):
    try:
        new_x = str(x).split(',')[1].strip()
    except IndexError as e:
            print(x)
            new_x = str(x).strip()
    return new_x

# %%
pd.set_option('display.max_rows', 150)

# %%
trip_df['Destination']
# Out:
# 0                         UK
# 1                   Thailand
# 2                  Indonesia
# 3                        USA
# 4                      Japan
# 5                     France
# 6                  Australia
# 7                     Brazil
# 8                Netherlands
# 9       United Arab Emirates
# 10                    Mexico
# 11                     Spain
# 12                    Hawaii
# 13                   Germany
# 14                   Morocco
# 15                  Scotland
# 16                     Paris
# 17                      Bali
# 18                    London
# 19                     Tokyo
# 20                  New York
# 21                    Sydney
# 22                      Rome
# 23                   Bangkok
# 24                     Paris
# 25                    Hawaii
# 26                 Barcelona
# 27                     Japan
# 28                  Thailand
# 29                    France
# 30                 Australia
# 31                    Brazil
# ...

# %%
trip_df['Destination']=trip_df['Destination'].apply(lambda x: substr_country(x))
# Out:
#  UK
#  Thailand
#  Indonesia
#  USA
#  Japan
#  France
#  Australia
#  Brazil
#  Netherlands
#  United Arab Emirates
#  Mexico
#  Spain
#  Hawaii
#  Germany
#  Morocco
#  Scotland
# Paris
# Bali
# London
# Tokyo
# New York
# Sydney
# Rome
# Bangkok
# Paris
# Hawaii
# Barcelona
# Japan
# Thailand
# France
# Australia
# Brazil
# Greece
# Egypt
# Mexico
# Italy
# Spain
# Canada
#  France
#  Australia
#  Japan
#  Mexico
#  Brazil
#  UK
#  Spain
#  USA
#  Thailand
#  Canada
#  Netherlands
#  France
#  Japan
#  AUS
#  USA
#  Brazil
#  Thailand
#  UK
#  Spain
#  South Korea
#  USA
#  Italy
# Paris
# Tokyo
# Cape Town
# Sydney
# Barcelona
# Bali
# Paris
# New York
# Bangkok
# Rome
# Bali
# nan
#  Indonesia
#  Japan
#  Mexico
#  France
#  SA
#  Indonesia
#  Aus
#  Thai
#  USA
#  Thai
#  Italy
# Paris
# Tokyo
# Bali
# Sydney
# New York
# London
# Dubai
# Bangkok
# Rome
# Bali
# Seoul
# Paris
# Tokyo
# Sydney
# London
# New York
# Rome
# Bangkok
# Cape Town
# Rio de Janeiro
# Bali
# Amsterdam
# ...

# %%
df = px.data.gapminder().query("year == 2007").query("continent == 'Europe'")
df.loc[df['pop'] < 2.e6, 'country'] = 'Other countries' # Represent only large countries
fig = px.pie(df, values='pop', names='country', title='Population of European continent')
fig.show()
